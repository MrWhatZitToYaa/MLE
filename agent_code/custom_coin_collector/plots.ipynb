# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np

# %%
def plot(input: list, title: str):
    y_label = title

    plt.figure(figsize=(10, 5))
    plt.plot(np.arange(0, len(input)), input)
    plt.xlabel('Episode')
    plt.ylabel(y_label)
    plt.title(title)
    plt.show()

# %%
with open("./monitor_training/total_rewards.pkl", "rb") as file:
    input = pickle.load(file)
    plot(input, "Rewards")

# %%
with open("./monitor_training/qTableSize.pkl", "rb") as file:
    input = pickle.load(file)
    plot(input, "qTableSize")
